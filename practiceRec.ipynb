# %%
#Print numbers from 1 to n
def numbers(n):
    if n == 0:
        return 
    numbers(n-1)
    print(n)

# %%
numbers(5)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
def revers(n):
    if n == 0:
        return 0 
    else:
        print(n)
        revers(n-1)

# %% [raw]
# print(revers(234))
